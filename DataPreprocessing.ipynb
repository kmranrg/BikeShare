# %%
#Importing Libraries

# %%
import pandas as pd
import numpy as np

# %%
#Dropping Columns

# %%
dt = pd.read_csv("Datasets/201402_trip_data.csv")
dt.head(10)
# Out:
#    Trip ID  Duration       Start Date             Start Station  \
# 0     4576        63  8/29/2013 14:13  South Van Ness at Market
# 1     4607        70  8/29/2013 14:42        San Jose City Hall
# 2     4130        71  8/29/2013 10:16   Mountain View City Hall
# 3     4251        77  8/29/2013 11:29        San Jose City Hall
# 4     4299        83  8/29/2013 12:02  South Van Ness at Market
# 5     4927       103  8/29/2013 18:54       Golden Gate at Polk
# 6     4500       109  8/29/2013 13:25    Santa Clara at Almaden
# 7     4563       111  8/29/2013 14:02       San Salvador at 1st
# 8     4760       113  8/29/2013 17:01  South Van Ness at Market
# 9     4258       114  8/29/2013 11:33        San Jose City Hall
#
#    Start Terminal         End Date               End Station  End Terminal  \
# 0              66  8/29/2013 14:14  South Van Ness at Market            66
# 1              10  8/29/2013 14:43        San Jose City Hall            10
# ...

# %%
to_drop = ["Subscription Type"]
dt.drop(to_drop, inplace=True, axis=1)

# %%
dt.head(10)
# Out:
#    Trip ID  Duration       Start Date             Start Station  \
# 0     4576        63  8/29/2013 14:13  South Van Ness at Market
# 1     4607        70  8/29/2013 14:42        San Jose City Hall
# 2     4130        71  8/29/2013 10:16   Mountain View City Hall
# 3     4251        77  8/29/2013 11:29        San Jose City Hall
# 4     4299        83  8/29/2013 12:02  South Van Ness at Market
# 5     4927       103  8/29/2013 18:54       Golden Gate at Polk
# 6     4500       109  8/29/2013 13:25    Santa Clara at Almaden
# 7     4563       111  8/29/2013 14:02       San Salvador at 1st
# 8     4760       113  8/29/2013 17:01  South Van Ness at Market
# 9     4258       114  8/29/2013 11:33        San Jose City Hall
#
#    Start Terminal         End Date               End Station  End Terminal  \
# 0              66  8/29/2013 14:14  South Van Ness at Market            66
# 1              10  8/29/2013 14:43        San Jose City Hall            10
# ...

# %%
#Index Change

# %%
dt["Trip ID"].is_unique
# Out:
# True

# %%
dt = dt.set_index("Trip ID")

# %%
dt.head(10)
# Out:
#          Duration       Start Date             Start Station  Start Terminal  \
# Trip ID
# 4576           63  8/29/2013 14:13  South Van Ness at Market              66
# 4607           70  8/29/2013 14:42        San Jose City Hall              10
# 4130           71  8/29/2013 10:16   Mountain View City Hall              27
# 4251           77  8/29/2013 11:29        San Jose City Hall              10
# 4299           83  8/29/2013 12:02  South Van Ness at Market              66
# 4927          103  8/29/2013 18:54       Golden Gate at Polk              59
# 4500          109  8/29/2013 13:25    Santa Clara at Almaden               4
# 4563          111  8/29/2013 14:02       San Salvador at 1st               8
# 4760          113  8/29/2013 17:01  South Van Ness at Market              66
# 4258          114  8/29/2013 11:33        San Jose City Hall              10
#
#                 End Date               End Station  End Terminal  Bike #  \
# Trip ID
# ...

# %%
dt.loc[4251]
# Out:
# Duration                          77
# Start Date           8/29/2013 11:29
# Start Station     San Jose City Hall
# Start Terminal                    10
# End Date             8/29/2013 11:30
# End Station       San Jose City Hall
# End Terminal                      10
# Bike #                            26
# Zip Code                       95060
# Name: 4251, dtype: object

# %%
#Data Analysis

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144015 entries, 4576 to 198775
# Data columns (total 9 columns):
# Duration          144015 non-null int64
# Start Date        144015 non-null object
# Start Station     144015 non-null object
# Start Terminal    144015 non-null int64
# End Date          144015 non-null object
# End Station       144015 non-null object
# End Terminal      144015 non-null int64
# Bike #            144015 non-null int64
# Zip Code          137885 non-null object
# dtypes: int64(4), object(5)
# memory usage: 16.0+ MB

# %%
dt.duplicated()
# Out:
# Trip ID
# 4576      False
# 4607      False
# 4130      False
# 4251      False
# 4299      False
# 4927      False
# 4500      False
# 4563      False
# 4760      False
# 4258      False
# 4549      False
# 4498      False
# 4965      False
# 4557      False
# 4386      False
# 4749      False
# 4242      False
# 4329      False
# 5097      False
# 5084      False
# 4982      False
# 4417      False
# 4265      False
# 5093      False
# 4168      False
# 4550      False
# 4533      False
# 4510      False
# 5070      False
# 4917      False
#           ...
# 198739    False
# 198742    False
# 198743    False
# 198744    False
# 198745    False
# 198746    False
# 198747    False
# 198748    False
# 198749    False
# 198750    False
# 198751    False
# 198752    False
# 198753    False
# 198754    False
# 198755    False
# 198757    False
# 198760    False
# 198761    False
# 198763    False
# 198764    False
# 198765    False
# 198766    False
# 198767    False
# 198768    False
# ...

# %%
#we will sum all above values to ensure there is no data redundancy
sum(dt.duplicated())
# Out:
# 0

# %%
#Fetching records from given duration value range

# %%
dt.shape
# Out:
# (144015, 9)

# %%
#fetching records where duration is greater than 100
dt[dt.Duration >= 100]
# Out:
#          Duration       Start Date  \
# Trip ID
# 4927          103  8/29/2013 18:54
# 4500          109  8/29/2013 13:25
# 4563          111  8/29/2013 14:02
# 4760          113  8/29/2013 17:01
# 4258          114  8/29/2013 11:33
# 4549          125  8/29/2013 13:52
# 4498          126  8/29/2013 13:23
# 4965          129  8/29/2013 19:32
# 4557          130  8/29/2013 13:57
# 4386          134  8/29/2013 12:31
# 4749          138  8/29/2013 16:57
# 4242          141  8/29/2013 11:25
# 4329          142  8/29/2013 12:11
# 5097          142  8/29/2013 22:21
# 5084          144  8/29/2013 22:06
# 4982          146  8/29/2013 19:42
# 4417          148  8/29/2013 12:45
# 4265          151  8/29/2013 11:40
# 5093          160  8/29/2013 22:12
# 4168          161  8/29/2013 10:56
# 4550          163  8/29/2013 13:53
# 4533          165  8/29/2013 13:43
# 4510          166  8/29/2013 13:31
# 5070          168  8/29/2013 21:43
# 4917          169  8/29/2013 18:45
# ...

# %%
#fetching records where Start Station is Golden Gate at Polk
dt[dt["Start Station"] == "Golden Gate at Polk"]
# Out:
#          Duration       Start Date        Start Station  Start Terminal  \
# Trip ID
# 4927          103  8/29/2013 18:54  Golden Gate at Polk              59
# 4705          193  8/29/2013 16:15  Golden Gate at Polk              59
# 4704          204  8/29/2013 16:15  Golden Gate at Polk              59
# 5002          236  8/29/2013 20:01  Golden Gate at Polk              59
# 4647          340  8/29/2013 15:26  Golden Gate at Polk              59
# 4955          360  8/29/2013 19:15  Golden Gate at Polk              59
# 4679          440  8/29/2013 15:54  Golden Gate at Polk              59
# 5013          440  8/29/2013 20:13  Golden Gate at Polk              59
# 5015          449  8/29/2013 20:13  Golden Gate at Polk              59
# 5014          538  8/29/2013 20:13  Golden Gate at Polk              59
# 5010          561  8/29/2013 20:12  Golden Gate at Polk              59
# 5009          690  8/29/2013 20:12  Golden Gate at Polk              59
# ...

# %%
#fetching records where End Station is Golden Gate at Polk
dt[dt["End Station"] == "Golden Gate at Polk"]
# Out:
#          Duration       Start Date  \
# Trip ID
# 4927          103  8/29/2013 18:54
# 4786          362  8/29/2013 17:14
# 4385          398  8/29/2013 12:30
# 4784          430  8/29/2013 17:13
# 4783          438  8/29/2013 17:13
# 4536          462  8/29/2013 13:44
# 4860          472  8/29/2013 17:59
# 4859          482  8/29/2013 17:59
# 4808          572  8/29/2013 17:27
# 4531          601  8/29/2013 13:41
# 4633          963  8/29/2013 15:09
# 4943          970  8/29/2013 19:06
# 4861         1015  8/29/2013 18:00
# 4862         1015  8/29/2013 18:00
# 5705          241  8/30/2013 13:46
# 5419          399  8/30/2013 11:40
# 5418          412  8/30/2013 11:40
# 5990          686  8/30/2013 15:37
# 5144          703   8/30/2013 8:02
# 6121         1588  8/30/2013 16:34
# 5115        18198   8/30/2013 3:00
# 5114        18206   8/30/2013 2:59
# 7010          311  8/31/2013 14:23
# 6616          870  8/31/2013 10:55
# 7334         1249  8/31/2013 18:05
# ...
